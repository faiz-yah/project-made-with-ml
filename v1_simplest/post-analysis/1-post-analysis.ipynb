# %%
import pandas as pd
import json

# %%
# with open('/Users/fabienyah/Documents/1DataScienceProject/5-github/project-made-with-ml/v1_simplest/results.jsonl') as f:
#     result = json.load(f)

# %%
df = pd.read_json('/Users/fabienyah/Documents/1DataScienceProject/5-github/project-made-with-ml/v1_simplest/results.jsonl', lines=True)

# %%
df = df.round(4)

# %%
df
# Out:
#                                           run_id  roc_auc_mean  accuracy_mean  \
# 0   ordinal_by_interval_extended_standard_logreg        0.8480         0.7822
# 1      ordinal_by_interval_extended_standard_xgb        0.8462         0.7958
# 2     ordinal_by_interval_extended_standard_lgbm        0.8593         0.8115
# 3       ordinal_by_interval_extended_standard_rf        0.8380         0.7935
# 4     ordinal_by_interval_extended_minmax_logreg        0.8506         0.7890
# ..                                           ...           ...            ...
# 67            target_custom_extended_standard_rf        0.8542         0.8092
# 68          target_custom_extended_minmax_logreg        0.8494         0.7890
# 69             target_custom_extended_minmax_xgb        0.8239         0.7733
# 70            target_custom_extended_minmax_lgbm        0.8524         0.8092
# 71              target_custom_extended_minmax_rf        0.8476         0.7935
#
# ...

# %%
df.sort_values(by='roc_auc_mean', ascending=False)
# Out:
#                                        run_id  roc_auc_mean  accuracy_mean  \
# 10      ordinal_by_frq_extended_standard_lgbm        0.8713         0.8104
# 14        ordinal_by_frq_extended_minmax_lgbm        0.8698         0.8160
# 46      frequency_custom_extended_minmax_lgbm        0.8696         0.8115
# 41     frequency_custom_extended_standard_xgb        0.8669         0.8059
# 45       frequency_custom_extended_minmax_xgb        0.8669         0.8059
# ..                                        ...           ...            ...
# 50  target_by_interval_extended_standard_lgbm        0.8344         0.8003
# 55      target_by_interval_extended_minmax_rf        0.8266         0.7957
# 53     target_by_interval_extended_minmax_xgb        0.8241         0.7891
# 69          target_custom_extended_minmax_xgb        0.8239         0.7733
# 61          target_by_frq_extended_minmax_xgb        0.8190         0.7846
#
# ...

# %%
df.sort_values(by='accuracy_mean', ascending=False)
# Out:
#                                             run_id  roc_auc_mean  \
# 38           frequency_by_frq_extended_minmax_lgbm        0.8667
# 26    frequency_by_interval_extended_standard_lgbm        0.8514
# 14             ordinal_by_frq_extended_minmax_lgbm        0.8698
# 22             ordinal_custom_extended_minmax_lgbm        0.8664
# 42         frequency_custom_extended_standard_lgbm        0.8662
# ..                                             ...           ...
# 24  frequency_by_interval_extended_standard_logreg        0.8506
# 61               target_by_frq_extended_minmax_xgb        0.8190
# 56          target_by_frq_extended_standard_logreg        0.8466
# 0     ordinal_by_interval_extended_standard_logreg        0.8480
# 69               target_custom_extended_minmax_xgb        0.8239
#
#     accuracy_mean  precision_mean  recall_mean  f1_mean   encoding  \
# 38         0.8171          0.7857       0.7221   0.7517  frequency
# ...

# %%
df.sort_values(by='precision_mean', ascending=False)
# Out:
#                                             run_id  roc_auc_mean  \
# 26    frequency_by_interval_extended_standard_lgbm        0.8514
# 67              target_custom_extended_standard_rf        0.8542
# 14             ordinal_by_frq_extended_minmax_lgbm        0.8698
# 22             ordinal_custom_extended_minmax_lgbm        0.8664
# 42         frequency_custom_extended_standard_lgbm        0.8662
# ..                                             ...           ...
# 48     target_by_interval_extended_standard_logreg        0.8456
# 28    frequency_by_interval_extended_minmax_logreg        0.8513
# 24  frequency_by_interval_extended_standard_logreg        0.8506
# 0     ordinal_by_interval_extended_standard_logreg        0.8480
# 69               target_custom_extended_minmax_xgb        0.8239
#
#     accuracy_mean  precision_mean  recall_mean  f1_mean   encoding  \
# 26         0.8160          0.7973       0.6989   0.7434  frequency
# ...

# %%
df.sort_values(by='f1_mean', ascending=False)
# Out:
#                                      run_id  roc_auc_mean  accuracy_mean  \
# 38    frequency_by_frq_extended_minmax_lgbm        0.8667         0.8171
# 9      ordinal_by_frq_extended_standard_xgb        0.8614         0.8137
# 13       ordinal_by_frq_extended_minmax_xgb        0.8614         0.8137
# 14      ordinal_by_frq_extended_minmax_lgbm        0.8698         0.8160
# 34  frequency_by_frq_extended_standard_lgbm        0.8668         0.8137
# ..                                      ...           ...            ...
# 56   target_by_frq_extended_standard_logreg        0.8466         0.7845
# 64   target_custom_extended_standard_logreg        0.8481         0.7857
# 62       target_by_frq_extended_minmax_lgbm        0.8536         0.7868
# 61        target_by_frq_extended_minmax_xgb        0.8190         0.7846
# 69        target_custom_extended_minmax_xgb        0.8239         0.7733
#
#     precision_mean  recall_mean  f1_mean   encoding binning feature_set  \
# ...
